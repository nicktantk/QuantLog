# %%
import pandas as pd
import vectorbt as vbt

tickers = ["META","AAPL","AMZN","NFLX","GOOG"]
prices = vbt.YFData.download(
    "META",
    start="2016-01-01 UTC",
    end="2020-08-31 UTC"
).get("Close")

fast_ma = vbt.MA.run(prices, 10, short_name="fast")
slow_ma = vbt.MA.run(prices, 30, short_name="slow")

entries = fast_ma.ma_crossed_above(slow_ma)
exits = fast_ma.ma_crossed_below(slow_ma)
pf = vbt.Portfolio.from_signals(prices, entries, exits)
pf.total_return(group_by="symbol").vbt.barplot()
entries
# Out:
# c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning:
#
# Unable to find acceptable character detection dependency (chardet or charset_normalizer).
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 17
#      15 exits = fast_ma.ma_crossed_below(slow_ma)
#      16 pf = vbt.Portfolio.from_signals(prices, entries, exits)
# ---> 17 pf.total_return(group_by="symbol").vbt.barplot()
#      18 entries
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:443, in cached_method.<locals>.decorator.<locals>.wrapper(instance, *args, **kwargs)
#     440 if not hashable:
#     441     # If not, do not invoke lru_cache
#     442     return func(instance, *args, **kwargs)
# --> 443 return cached_func(*args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:413, in cached_method.<locals>.decorator.<locals>.wrapper.<locals>.partial_func(*args, **kwargs)
#     411 def partial_func(*args, **kwargs) -> tp.Any:
#     412     # Ignores non-hashable instances
# --> 413     return func(instance, *args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\portfolio\base.py:4383, in Portfolio.total_return(self, group_by, wrap_kwargs)
#    4379 @cached_method
#    4380 def total_return(self, group_by: tp.GroupByLike = None,
#    4381                  wrap_kwargs: tp.KwargsLike = None) -> tp.MaybeSeries:
#    4382     """Get total profit per column/group."""
# -> 4383     init_cash = to_1d_array(self.get_init_cash(group_by=group_by))
#    4384     total_profit = to_1d_array(self.total_profit(group_by=group_by))
#    4385     total_return = nb.total_return_nb(total_profit, init_cash)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:443, in cached_method.<locals>.decorator.<locals>.wrapper(instance, *args, **kwargs)
#     440 if not hashable:
#     441     # If not, do not invoke lru_cache
#     442     return func(instance, *args, **kwargs)
# --> 443 return cached_func(*args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:413, in cached_method.<locals>.decorator.<locals>.wrapper.<locals>.partial_func(*args, **kwargs)
#     411 def partial_func(*args, **kwargs) -> tp.Any:
#     412     # Ignores non-hashable instances
# --> 413     return func(instance, *args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\portfolio\base.py:4232, in Portfolio.get_init_cash(self, group_by, wrap_kwargs)
#    4230 init_cash = to_1d_array(self._init_cash)
#    4231 if self.wrapper.grouper.is_grouped(group_by=group_by):
# -> 4232     group_lens = self.wrapper.grouper.get_group_lens(group_by=group_by)
#    4233     init_cash = nb.init_cash_grouped_nb(init_cash, group_lens, self.cash_sharing)
#    4234 else:
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:443, in cached_method.<locals>.decorator.<locals>.wrapper(instance, *args, **kwargs)
#     440 if not hashable:
#     441     # If not, do not invoke lru_cache
#     442     return func(instance, *args, **kwargs)
# --> 443 return cached_func(*args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:413, in cached_method.<locals>.decorator.<locals>.wrapper.<locals>.partial_func(*args, **kwargs)
#     411 def partial_func(*args, **kwargs) -> tp.Any:
#     412     # Ignores non-hashable instances
# --> 413     return func(instance, *args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\base\column_grouper.py:273, in ColumnGrouper.get_group_lens(self, group_by, **kwargs)
#     270 @cached_method
#     271 def get_group_lens(self, group_by: tp.GroupByLike = None, **kwargs) -> tp.Array1d:
#     272     """See get_group_lens_nb."""
# --> 273     if not self.is_sorted(group_by=group_by):
#     274         raise ValueError("group_by must lead to groups that are coherent and sorted "
#     275                          "(such as [0, 0, 1, 2, 2, ...])")
#     276     group_by = self.resolve_group_by(group_by=group_by, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:443, in cached_method.<locals>.decorator.<locals>.wrapper(instance, *args, **kwargs)
#     440 if not hashable:
#     441     # If not, do not invoke lru_cache
#     442     return func(instance, *args, **kwargs)
# --> 443 return cached_func(*args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\decorators.py:413, in cached_method.<locals>.decorator.<locals>.wrapper.<locals>.partial_func(*args, **kwargs)
#     411 def partial_func(*args, **kwargs) -> tp.Any:
#     412     # Ignores non-hashable instances
# --> 413     return func(instance, *args, **kwargs)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\base\column_grouper.py:266, in ColumnGrouper.is_sorted(self, group_by, **kwargs)
#     263 @cached_method
#     264 def is_sorted(self, group_by: tp.GroupByLike = None, **kwargs) -> bool:
#     265     """Return whether groups are coherent and sorted."""
# --> 266     group_by = self.resolve_group_by(group_by=group_by, **kwargs)
#     267     groups = self.get_groups(group_by=group_by)
#     268     return is_sorted(groups)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\base\column_grouper.py:247, in ColumnGrouper.resolve_group_by(self, group_by, **kwargs)
#     245     group_by = None
#     246 self.check_group_by(group_by=group_by, **kwargs)
# --> 247 return group_by_to_index(self.columns, group_by)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\base\column_grouper.py:35, in group_by_to_index(index, group_by)
#      33     group_by = pd.Index(['group'] * len(index))  # one group
#      34 elif isinstance(group_by, (int, str)):
# ---> 35     group_by = index_fns.select_levels(index, group_by)
#      36 elif checks.is_sequence(group_by):
#      37     if len(group_by) != len(index) \
#      38             and isinstance(group_by[0], (int, str)) \
#      39             and isinstance(index, pd.MultiIndex) \
#      40             and len(group_by) <= len(index.names):
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\base\index_fns.py:189, in select_levels(index, level_names)
#     187 def select_levels(index: tp.Index, level_names: tp.MaybeLevelSequence) -> tp.Index:
#     188     """Build a new index by selecting one or multiple `level_names` from `index`."""
# --> 189     checks.assert_instance_of(index, pd.MultiIndex)
#     191     if isinstance(level_names, (int, str)):
#     192         return index.get_level_values(level_names)
#
# File c:\Users\nickt\anaconda3\envs\my-quant-stack\lib\site-packages\vectorbt\utils\checks.py:311, in assert_instance_of(arg, types)
#     309     raise AssertionError(f"Type must be one of {types}, not {type(arg)}")
#     310 else:
# --> 311     raise AssertionError(f"Type must be {types}, not {type(arg)}")
#
# AssertionError: Type must be <class 'pandas.core.indexes.multi.MultiIndex'>, not <class 'pandas.core.indexes.base.Index'>
